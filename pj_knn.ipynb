# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# products = pd.read_csv('./products.csv')
products = pd.read_csv('./products_join_categories.csv')

products.sample(10)
# Out:
#         Unnamed: 0  productId  \
# 85197        85197      85197
# 490009      490009     490009
# 357810      357810     357810
# 125592      125592     125592
# 234296      234296     234296
# 141292      141292     141292
# 242729      242729     242729
# 437617      437617     437617
# 373994      373994     373994
# 64              64         64
#
#                                                      name         catIds  \
# 85197                                               列王纪研究    832,519,599
# 490009                                      卡徒.第4季(经典珍藏本)    832,519,402
# 357810  The Tasha Tudor Cookbook: Recipes and Reminisc...    832,476,923
# 125592                         Li Ning 李宁 女 休闲运动鞋 ALMG038    518,884,460
# 234296  Rapoo 雷柏 N6000USB有线光学对称鼠标(白)(舒适的外形 时尚靓丽色彩设计 分辨...   1057,439,736
# 141292             婴儿游戏绘本-全10册,全球知名亲子互动游戏书,快快乐乐培养婴儿各种良好习惯  832,1101,1086
# 242729                             尤????戈留塔画集:俄罗斯当代写实主义画家   832,519,1076
# 437617                                         脂肪肝合理用药与食疗   832,665,1011
# 373994                                           妇产科超声诊断学   832,1096,867
# 64                             The Summer Before the Dark    832,476,923
#
#         cat1 cat1_name  cat2 cat2_name    cat3 cat3_name
# 85197    832      图书音像   519      文学艺术   599.0       文学类
# 490009   832      图书音像   519      文学艺术   402.0      青春文学
# 357810   832      图书音像   476      其它图书   923.0      进口图书
# 125592   518      鞋类箱包   884       运动鞋   460.0       跑步鞋
# 234296  1057     电脑/办公   439      外设产品   736.0        鼠标
# 141292   832      图书音像  1101   少儿/教育图书  1086.0        少儿
# 242729   832      图书音像   519      文学艺术  1076.0        艺术
# 437617   832      图书音像   665     生活类图书  1011.0     保健/养生
# 373994   832      图书音像  1096     科技类图书   867.0        医学
# 64       832      图书音像   476      其它图书   923.0      进口图书

# %%
model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=20, n_jobs=-1)
model_knn.fit(products)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d40c760e9b78> in <module>
#       1 model_knn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=20, n_jobs=-1)
# ----> 2 model_knn.fit(products)
#
# c:\python37\lib\site-packages\sklearn\neighbors\_base.py in fit(self, X, y)
#    1166             or [n_samples, n_samples] if metric='precomputed'.
#    1167         """
# -> 1168         return self._fit(X)
#
# c:\python37\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X)
#     397             X = _check_precomputed(X)
#     398         else:
# --> 399             X = check_array(X, accept_sparse='csr')
#     400
#     401         n_samples = X.shape[0]
#
# c:\python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     513                     array = array.astype(dtype, casting="unsafe", copy=False)
#     514                 else:
# --> 515                     array = np.asarray(array, order=order, dtype=dtype)
#     516             except ComplexWarning:
#     517                 raise ValueError("Complex data not supported\n"
#
# c:\python37\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'CSSMs Biology: Control in Cells and in Organisms Unit 5'
